# %%
import numpy as np
import pandas as pd

# %%
pd.read_

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8472 entries, 0 to 8471
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  8472 non-null   int64
#  1   government_id       1538 non-null   object
#  2   diagnosed_date      8472 non-null   object
#  3   age                 1190 non-null   object
#  4   gender              1967 non-null   object
#  5   detected_city       1123 non-null   object
#  6   detected_district   6848 non-null   object
#  7   detected_state      8472 non-null   object
#  8   nationality         1195 non-null   object
#  9   current_status      8471 non-null   object
#  10  status_change_date  8362 non-null   object
#  11  notes               7272 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 794.4+ KB

# %%
df['current_status'].value_counts()
# Out:
# Hospitalized    8301
# Recovered        139
# Deceased          30
# Migrated           1
# Name: current_status, dtype: int64

# %%
total = df.shape[0]
total
# Out:
# 8472

# %%
df[df['current_status']=='Hospitalized'].shape[0]
# Out:
# 8301

# %%
hospitalized = df[df['current_status']=='Hospitalized'].shape[0]
hospitalized
# Out:
# 8301

# %%
recovered = df[df['current_status']=='Recovered'].shape[0]
recovered
# Out:
# 139

# %%
deaths = df[df['current_status']=='Deceased'].shape[0]
deaths
# Out:
# 30

# %%
df['detected_state'].value_counts().reset_index()
# Out:
#                           index  detected_state
# 0                   Maharashtra            1761
# 1                         Delhi            1069
# 2                    Tamil Nadu             969
# 3                     Rajasthan             700
# 4                Madhya Pradesh             529
# 5                     Telangana             503
# 6                       Gujarat             468
# 7                 Uttar Pradesh             452
# 8                Andhra Pradesh             405
# 9                        Kerala             373
# 10                    Karnataka             226
# 11            Jammu and Kashmir             224
# 12                      Haryana             179
# 13                       Punjab             158
# 14                  West Bengal             134
# 15                        Bihar              64
# 16                       Odisha              54
# 17                  Uttarakhand              35
# 18             Himachal Pradesh              32
# ...

# %%
df
# Out:
#         id government_id diagnosed_date  age gender             detected_city  \
# 0        0      KL-TS-P1     30/01/2020   20      F                  Thrissur
# 1        1      KL-AL-P1     02/02/2020  NaN    NaN                 Alappuzha
# 2        2      KL-KS-P1     03/02/2020  NaN    NaN                 Kasaragod
# 3        3         DL-P1     02/03/2020   45      M  East Delhi (Mayur Vihar)
# 4        4         TS-P1     02/03/2020   24      M                 Hyderabad
# ...    ...           ...            ...  ...    ...                       ...
# 8467  8468           NaN     12/04/2020  NaN    NaN                       NaN
# 8468  8469           NaN     12/04/2020  NaN    NaN                       NaN
# 8469  8470           NaN     12/04/2020  NaN    NaN                       NaN
# 8470  8471           NaN     12/04/2020  NaN    NaN                       NaN
# 8471  8472           NaN     12/04/2020  NaN    NaN                       NaN
#
# ...

# %%
df1 = df[df['current_status'] == 'Hospitalized']
df1['detected_state'].value_counts()
# Out:
# Maharashtra                    1757
# Delhi                          1065
# Tamil Nadu                      962
# Rajasthan                       696
# Madhya Pradesh                  527
# Telangana                       501
# Gujarat                         463
# Uttar Pradesh                   445
# Andhra Pradesh                  403
# Kerala                          313
# Jammu and Kashmir               223
# Karnataka                       181
# Haryana                         167
# Punjab                          156
# West Bengal                     128
# Bihar                            63
# Odisha                           53
# Uttarakhand                      34
# Himachal Pradesh                 30
# Assam                            29
# Chhattisgarh                     24
# Chandigarh                       19
# Jharkhand                        17
# Ladakh                           15
# Andaman and Nicobar Islands      11
# Puducherry                        7
# ...

# %%
df1.detected_state.value_counts()
# Out:
# Maharashtra                    1757
# Delhi                          1065
# Tamil Nadu                      962
# Rajasthan                       696
# Madhya Pradesh                  527
# Telangana                       501
# Gujarat                         463
# Uttar Pradesh                   445
# Andhra Pradesh                  403
# Kerala                          313
# Jammu and Kashmir               223
# Karnataka                       181
# Haryana                         167
# Punjab                          156
# West Bengal                     128
# Bihar                            63
# Odisha                           53
# Uttarakhand                      34
# Himachal Pradesh                 30
# Assam                            29
# Chhattisgarh                     24
# Chandigarh                       19
# Jharkhand                        17
# Ladakh                           15
# Andaman and Nicobar Islands      11
# Puducherry                        7
# ...

# %%
option = df.groupby('current_status')

# %%
option.get_group('Recovered')['detected_state'].value_counts().reset_index()
# Out:
#                index  detected_state
# 0             Kerala              58
# 1          Karnataka              39
# 2            Haryana              12
# 3      Uttar Pradesh               6
# 4         Tamil Nadu               6
# 5          Rajasthan               3
# 6        West Bengal               3
# 7              Delhi               2
# 8        Maharashtra               2
# 9     Andhra Pradesh               2
# 10         Telangana               1
# 11      Chhattisgarh               1
# 12       Uttarakhand               1
# 13           Gujarat               1
# 14  Himachal Pradesh               1
# 15           Manipur               1

# %%
options = df.groupby('current_status')
def getGroup(option):
    return options.get_group(option)['detected_state'].value_counts().reset_index()

getGroup('Recovered')
# Out:
#                index  detected_state
# 0             Kerala              58
# 1          Karnataka              39
# 2            Haryana              12
# 3      Uttar Pradesh               6
# 4         Tamil Nadu               6
# 5          Rajasthan               3
# 6        West Bengal               3
# 7              Delhi               2
# 8        Maharashtra               2
# 9     Andhra Pradesh               2
# 10         Telangana               1
# 11      Chhattisgarh               1
# 12       Uttarakhand               1
# 13           Gujarat               1
# 14  Himachal Pradesh               1
# 15           Manipur               1
